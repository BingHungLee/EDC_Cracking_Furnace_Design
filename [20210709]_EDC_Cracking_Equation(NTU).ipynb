# %% [markdown]
# <a href="https://colab.research.google.com/github/BingHungLee/EDC_Cracking_Furnace_Design/blob/main/%5B20210709%5D_EDC_Cracking_Equation(NTU).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
################################################################################
# INSTALL CONDA AND CANTERA ON GOOGLE COLAB
################################################################################
! wget https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
! chmod +x Miniconda3-py37_4.8.2-Linux-x86_64.sh
! bash ./Miniconda3-py37_4.8.2-Linux-x86_64.sh -b -f -p /usr/local
import sys
sys.path.append('/usr/local/lib/python3.7/site-packages/')
# Out:
# --2021-07-09 08:11:04--  https://repo.anaconda.com/miniconda/Miniconda3-py37_4.8.2-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.130.3, 104.16.131.3, 2606:4700::6810:8303, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.130.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 85055499 (81M) [application/x-sh]
# Saving to: ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’
#
# Miniconda3-py37_4.8 100%[===================>]  81.12M   162MB/s    in 0.5s
#
# 2021-07-09 08:11:05 (162 MB/s) - ‘Miniconda3-py37_4.8.2-Linux-x86_64.sh’ saved [85055499/85055499]
#
# PREFIX=/usr/local
# Unpacking payload ...
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - _libgcc_mutex==0.1=main
#     - asn1crypto==1.3.0=py37_0
#     - ca-certificates==2020.1.1=0
#     - certifi==2019.11.28=py37_0
#     - cffi==1.14.0=py37h2e261b9_0
#     - chardet==3.0.4=py37_1003
# ...

# %%
# !conda install --channel cantera cantera ipython matplotlib jupyter
# Out:
# done
# failed with initial frozen solve. Retrying with flexible solve.
# failed with repodata from current_repodata.json, will retry with next repodata source.
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - cantera
#     - ipython
#     - jupyter
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     argon2-cffi-20.1.0         |   py37h27cfd23_1          46 KB
#     async_generator-1.10       |   py37h28b3542_0          39 KB
#     attrs-21.2.0               |     pyhd3eb1b0_0          46 KB
#     backcall-0.2.0             |     pyhd3eb1b0_0          13 KB
#     blas-1.0                   |              mkl           6 KB
#     bleach-3.3.0               |     pyhd3eb1b0_0         113 KB
#     ca-certificates-2021.7.5   |       h06a4308_1         113 KB
# ...

# %%
import cantera as ct
import numpy as np

# %%
# !git clone https://github.com/BingHungLee/EDC_Cracking_Furnace_Design.git
# Out:
# Cloning into 'EDC_Cracking_Furnace_Design'...
# remote: Enumerating objects: 39, done.
# remote: Counting objects: 100% (39/39), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 39 (delta 19), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (39/39), done.

# %%
cd /content/EDC_Cracking_Furnace_Design
# Out:
# /content/EDC_Cracking_Furnace_Design

# %%
# !unzip 20210708_0606_Cantera.zip -d my_data
# Out:
# Archive:  20210708_0606_Cantera.zip
#    creating: my_data/0606/
#    creating: my_data/0606/.mypy_cache/
#    creating: my_data/0606/.mypy_cache/3.7/
#   inflating: my_data/0606/.mypy_cache/3.7/abc.data.json
#   inflating: my_data/0606/.mypy_cache/3.7/abc.meta.json
#   inflating: my_data/0606/.mypy_cache/3.7/ast.data.json
#   inflating: my_data/0606/.mypy_cache/3.7/ast.meta.json
#   inflating: my_data/0606/.mypy_cache/3.7/codecs.data.json
#   inflating: my_data/0606/.mypy_cache/3.7/codecs.meta.json
#   inflating: my_data/0606/.mypy_cache/3.7/io.data.json
#   inflating: my_data/0606/.mypy_cache/3.7/io.meta.json
#    creating: my_data/0606/.mypy_cache/3.7/os/
#   inflating: my_data/0606/.mypy_cache/3.7/os/__init__.data.json
#   inflating: my_data/0606/.mypy_cache/3.7/os/__init__.meta.json
#   inflating: my_data/0606/.mypy_cache/3.7/posix.data.json
#   inflating: my_data/0606/.mypy_cache/3.7/posix.meta.json
#   inflating: my_data/0606/.mypy_cache/3.7/types.data.json
# ...

# %%
cd /content/EDC_Cracking_Furnace_Design/my_data/0606
# Out:
# /content/EDC_Cracking_Furnace_Design/my_data/0606

# %%
# !conda env create -f environment.yml
# Out:
# done
# failed
#
# ResolvePackageNotFound:
#   - six==1.15.0=py37haa95532_0
#   - markdown==3.3.4=py37haa95532_0
#   - freetype==2.10.4=hd328e21_0
#   - pip==21.0.1=py37haa95532_0
#   - kiwisolver==1.3.1=py37hd77b12b_0
#   - openssl==1.1.1k=h2bbff1b_0
#   - zlib==1.2.11=h62dcd97_4
#   - ipython==7.22.0=py37hd4e2768_0
#   - ca-certificates==2021.4.13=haa95532_1
#   - cffi==1.14.5=py37hcd4344a_0
#   - jpeg==9b=hb83a4c4_2
#   - python==3.7.6=h60c2a47_2
#   - matplotlib-base==3.3.4=py37h49ac443_0
#   - psutil==5.8.0=py37h2bbff1b_1
#   - typed-ast==1.4.2=py37h2bbff1b_1
#   - absl-py==0.12.0=py37haa95532_0
#   - numpy==1.19.2=py37hadc3359_0
#   - blinker==1.4=py37haa95532_0
#   - scikit-learn==0.23.2=py37h47e9c7a_0
#   - libpng==1.6.37=h2a8f88b_0
#   - sip==4.19.8=py37h6538335_0
#   - icc_rt==2019.0.0=h0cc432a_1
#   - wrapt==1.12.1=py37he774522_1
#   - certifi==2020.12.5=py37haa95532_0
#   - powershell_shortcut==0.0.1=3
#   - mkl-service==2.3.0=py37h196d8e1_0
#   - vc==14.2=h21ff451_1
# ...

# %%
# !pip install silence_tensorflow
# Out:
# ...
#   Created wheel for silence-tensorflow: filename=silence_tensorflow-1.1.1-py3-none-any.whl size=3737 sha256=4dfc13efbde162b6affdd3ef22ad25e895785c9c703479801b0c88a4396a1f84
#   Stored in directory: /root/.cache/pip/wheels/a2/42/cf/26148cd545b324903a62edde56cfc4502b278c104a07bb6b96
# Successfully built silence-tensorflow
# ...

# %%
# !pip install sklearn
# Out:
# ...
#      |████████████████████████████████| 22.3 MB 31.5 MB/s
# ...
#      |████████████████████████████████| 303 kB 45.4 MB/s
# ...
#      |████████████████████████████████| 28.5 MB 40 kB/s
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1315 sha256=595077611de88e6b08584e8105a2ab22f9d8fe5b586e0257a9af3c723e4518da
#   Stored in directory: /root/.cache/pip/wheels/46/ef/c3/157e41f5ee1372d1be90b09f74f82b10e391eaacca8f22d33e
# Successfully built sklearn
# ...

# %%
# !pip install keras
# !pip install tensorflow
# Out:
# ...
#      |████████████████████████████████| 636 kB 26.0 MB/s
# ...
#      |████████████████████████████████| 454.3 MB 16 kB/s
# ...
#      |████████████████████████████████| 4.0 MB 25.7 MB/s
# ...
#      |████████████████████████████████| 42 kB 1.2 MB/s
# ...
#      |████████████████████████████████| 462 kB 45.9 MB/s
# ...
#      |████████████████████████████████| 6.0 MB 29.3 MB/s
# ...
#      |████████████████████████████████| 14.8 MB 161 kB/s
# ...
#      |████████████████████████████████| 1.0 MB 52.4 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 30.2 MB/s
# ...
#      |████████████████████████████████| 65 kB 4.0 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 28.6 MB/s
# ...
#      |████████████████████████████████| 132 kB 57.8 MB/s
# ...
#      |████████████████████████████████| 57 kB 4.5 MB/s
# ...
#      |████████████████████████████████| 147 kB 56.7 MB/s
# ...
#      |████████████████████████████████| 781 kB 63.8 MB/s
# ...
#      |████████████████████████████████| 4.9 MB 46.1 MB/s
# ...
#      |████████████████████████████████| 288 kB 53.6 MB/s
# ...

# %%
# !python ML_model_final.py
# Out:
# 2021-07-09 08:22:05.093432: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# mass:(T/H) The input should be between 27 and 36 for 20-ton scale and 53 for 30-ton scale
# 53
# pressure:(kg/cm2G) The input should be within 10.4 and 14.4.
# 13
# CCl4:(ppm) The input should be smaller than 2500.
# 1000
# Temperature: please separate the data points by ","
# ex:350,368,382,400,409,415,421,427,433,440,445,450,453,456,459,462,465,468,471
# 350,368,382,400,409,415,421,427,433,440,445,450,453,456,459,462,465,468,471
# len: 19
# Start the prediction...
# cracking rates are:
# /usr/local/lib/python3.7/site-packages/sklearn/base.py:315: UserWarning: Trying to unpickle estimator StandardScaler from version 0.23.2 when using version 0.24.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# ...
